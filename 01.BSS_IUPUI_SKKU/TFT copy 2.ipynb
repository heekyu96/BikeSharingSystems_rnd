# %% [markdown]
# - static covariates: do not change through the course of the timeseries.
# station name
#
# - time series covariates
# -- known in advance: day of week, month, holidays, time index
# -- unknown in advance: event class
#
# station name, time index, bike counts, class

# %%
import pandas as pd

# %%
import os

directory = 'C:/Users/huigyu/workspace/BikeSharingSystems_rnd/03.Data/xx.chicago_bike_dataset/use_historical'

dfs = []

for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath, names = ["ID",
                              "Timestamp",
                              "Station Name",
                              "Address",
                              "Total Docks",
                              "Docks in Service",
                              "Available Docks",
                              "Available Bikes",
                              "Percent Full",
                              "Status",
                              "Latitude",
                              "Longitude",
                              "Location",
                              "Record"])
        dfs.append(df)

data = pd.concat(dfs, axis=0, ignore_index = True)

# %%
data
# Out:
#           ID               Timestamp                         Station Name  \
# 0         48  12/10/2019 12:15:13 AM           Larrabee St & Kingsbury St
# 1        100  12/10/2019 12:15:13 AM  Orleans St & Merchandise Mart Plaza
# 2        101  12/10/2019 12:15:13 AM                        63rd St Beach
# 3        102  12/10/2019 12:15:13 AM           Stony Island Ave & 67th St
# 4        103  12/10/2019 12:15:13 AM                 Clinton St & Polk St
# ...      ...                     ...                                  ...
# 1562322  648  12/31/2019 11:55:54 PM               Carpenter St & 63rd St
# 1562323  649  12/31/2019 11:55:54 PM            Stewart Ave & 63rd St (*)
# 1562324  650  12/31/2019 11:55:54 PM          Eggleston Ave & 69th St (*)
# 1562325  651  12/31/2019 11:55:54 PM               Michigan Ave & 71st St
# 1562326  652  12/31/2019 11:55:54 PM                 Rhodes Ave & 71st St
#
#          Address  Total Docks  Docks in Service  Available Docks  \
# ...

# %%
data.drop(['Address','Latitude', 'Longitude', 'Location', 'Record', 'Status', 'Station Name'], axis = 1, inplace = True)

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

data['month'] = data['Timestamp'].dt.month
data['day'] = data['Timestamp'].dt.day
data['hour'] = data['Timestamp'].dt.hour
data['minute'] = data['Timestamp'].dt.minute
# Out:
# C:\Users\huigyu\AppData\Local\Temp\ipykernel_18344\2894684264.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# %%
data
# Out:
#           ID           Timestamp  Total Docks  Docks in Service  \
# 0         48 2019-12-10 00:15:13           43                43
# 1        100 2019-12-10 00:15:13           35                35
# 2        101 2019-12-10 00:15:13           15                15
# 3        102 2019-12-10 00:15:13           11                11
# 4        103 2019-12-10 00:15:13           15                15
# ...      ...                 ...          ...               ...
# 1562322  648 2019-12-31 23:55:54            7                 7
# 1562323  649 2019-12-31 23:55:54           12                12
# 1562324  650 2019-12-31 23:55:54           12                11
# 1562325  651 2019-12-31 23:55:54            7                 7
# 1562326  652 2019-12-31 23:55:54           11                11
#
#          Available Docks  Available Bikes  Percent Full  month  day  hour  \
# 0                     43                0             0     12   10     0
# ...

# %%
data.drop(['Timestamp', 'Docks in Service'], axis = 1, inplace = True)

# %%
data
# Out:
#           ID  Total Docks  Available Docks  Available Bikes  Percent Full  \
# 0         48           43               43                0             0
# 1        100           35               16               19            54
# 2        101           15                9                6            40
# 3        102           11                5                6            55
# 4        103           15               10                5            33
# ...      ...          ...              ...              ...           ...
# 1562322  648            7                3                4            57
# 1562323  649           12                5                7            58
# 1562324  650           12                7                4            36
# 1562325  651            7                5                2            29
# 1562326  652           11                6                5            45
#
#          month  day  hour  minute
# 0           12   10     0      15
# ...
